# %% [markdown]
# # Laboratory 1: Property Graphs
# ### Luis Alfredo Leon Villapún
# ### Liliia Aliakberova
#
# # Part A.2 Instantiating / Loading
# * * *
# In this section we are asked to load the data into our desired graph. To do this, we are going to use mainly a modified version of the <a href="https://www.kaggle.com/datasets/dpixton/byu-engineering-publications-in-scopus-201721?resource=download">BYU Engineering Publications in Scopus 2017-21</a> from Kaggle.
# Please note that:
# - this datasets contain modified information to suit this tasks requirements, so even though a part of this dataset is real, some of the enforced relationships will be fake. Keep in mind this is for the purpose of the lab.
#
# ## Creating the connector
# Let's first create the connector to handle the messages with Neo4j.

# %%
# Install if needed
# !pip install neo4j
# !pip install pandas

# %%
from connector import Neo4jConnector
from getpass import getpass

uri = "neo4j://localhost:7687"
user = "neo4j"
password = getpass("Input your password to connect")
conn = Neo4jConnector(uri, user, password)
# Out:
# Input your password to connect········

# %%
# Uncomment to drop the database (you will have to rerun the loading cells)
conn.drop()

# %% [markdown]
# ## CSV Data Exploration
# First, let's perform a quick data exploration on the dataset we want to use.

# %%
import pandas as pd
byupath = "/Users/alfredo.leon/Desktop/SDMLab1/PropertyGraphsLab/neo4jcontainerdata/scopusBYUEngr17_21.csv"

byu = pd.read_csv(byupath)
byu.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 890 entries, 0 to 889
# Data columns (total 24 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Authors                    890 non-null    object
#  1   Author(s) ID               890 non-null    object
#  2   Title                      890 non-null    object
#  3   Year                       890 non-null    int64
#  4   Source title               890 non-null    object
#  5   Volume                     706 non-null    object
#  6   Issue                      368 non-null    object
#  7   Art. No.                   334 non-null    object
#  8   Page start                 505 non-null    object
#  9   Page end                   501 non-null    object
#  10  Page count                 27 non-null     float64
#  11  Cited by                   532 non-null    float64
#  12  DOI                        775 non-null    object
#  13  Link                       890 non-null    object
#  14  Affiliations               890 non-null    object
#  15  Authors with affiliations  890 non-null    object
#  16  Abstract                   890 non-null    object
#  17  Author Keywords            493 non-null    object
#  18  Index Keywords             787 non-null    object
#  19  Document Type              890 non-null    object
#  20  Publication Stage          890 non-null    object
#  21  Access Type                110 non-null    object
#  22  Source                     890 non-null    object
#  23  EID                        890 non-null    object
# dtypes: float64(2), int64(1), object(21)
# memory usage: 167.0+ KB

# %%
byu.head(n=1).T
# Out:
#                                                                            0
# Authors                              Gautam A., Crandall J.W., Goodrich M.A.
# Author(s) ID                              57218202833;7004904337;7005513246;
# Title                      Self-assessment of Proficiency of Intelligent ...
# Year                                                                    2021
# Source title                   Advances in Intelligent Systems and Computing
# Volume                                                             1210 AISC
# Issue                                                                    NaN
# Art. No.                                                                 NaN
# Page start                                                               108
# Page end                                                                 113
# Page count                                                               NaN
# Cited by                                                                 NaN
# DOI                                             10.1007/978-3-030-51758-8_15
# Link                       https://www.scopus.com/inward/record.uri?eid=2...
# Affiliations               Computer Science Department, Brigham Young Uni...
# Authors with affiliations  Gautam, A., Computer Science Department, Brigh...
# Abstract                   Autonomous systems, although capable of perfor...
# Author Keywords            Environment; Goal(s); Intelligent agents; Prof...
# Index Keywords             Drones; Human engineering; Intelligent systems...
# Document Type                                               Conference Paper
# Publication Stage                                                      Final
# Access Type                                                              NaN
# Source                                                                Scopus
# EID                                                       2-s2.0-85088238482

# %%
byu['Document Type'].unique()
# Out:
# array(['Conference Paper', 'Review', 'Article', 'Note', 'Book Chapter',
#        'Editorial', 'Book', 'Short Survey', 'Erratum'], dtype=object)

# %%
byu.loc[byu['Document Type'] == 'Review'].head().T
# Out:
#                                                                          2    \
# Authors                                     Hajimirzaie S.M., Hotchkiss R.H.
# Author(s) ID                                        53879700900;26642910500;
# Title                      Development of sediment management guidelines ...
# Year                                                                    2020
# Source title                                Journal of Hydraulic Engineering
# Volume                                                                   146
# Issue                                                                     12
# Art. No.                                                            02520004
# Page start                                                               NaN
# Page end                                                                 NaN
# Page count                                                               NaN
# Cited by                                                                 NaN
# DOI                                       10.1061/(ASCE)HY.1943-7900.0001822
# Link                       https://www.scopus.com/inward/record.uri?eid=2...
# Affiliations               Task Committee Secretary and Lead Engineer, Op...
# Authors with affiliations  Hajimirzaie, S.M., Task Committee Secretary an...
# Abstract                   Forum papers are thought-provoking opinion pie...
# Author Keywords                                                          NaN
# Index Keywords             Hydraulics; Editorial board; Sediment manageme...
# Document Type                                                         Review
# Publication Stage                                                      Final
# Access Type                                                              NaN
# Source                                                                Scopus
# EID                                                       2-s2.0-85091917202
#
#                                                                          92   \
# Authors                    Wnorowska U., Fiedoruk K., Piktel E., Prasad S...
# Author(s) ID               56685601500;16549438300;56685789300;5721275745...
# Title                      Nanoantibiotics containing membrane-active hum...
# Year                                                                    2020
# Source title                                    Journal of Nanobiotechnology
# Volume                                                                    18
# Issue                                                                      1
# Art. No.                                                                   3
# Page start                                                               NaN
# Page end                                                                 NaN
# Page count                                                               NaN
# Cited by                                                                 4.0
# DOI                                                10.1186/s12951-019-0566-z
# Link                       https://www.scopus.com/inward/record.uri?eid=2...
# Affiliations               Department of Medical Microbiology and Nanobio...
# Authors with affiliations  Wnorowska, U., Department of Medical Microbiol...
# Abstract                   Nanotechnology-based therapeutic approaches ha...
# Author Keywords            Ceragenins; Human cathelicidin; LL-37 peptide;...
# Index Keywords             Antimicrobial agents; Biocompatibility; Medica...
# Document Type                                                         Review
# Publication Stage                                                      Final
# Access Type                                                      Open Access
# Source                                                                Scopus
# EID                                                       2-s2.0-85077450344
#
#                                                                          124  \
# Authors                                Ling M., Howell L.L., Cao J., Chen G.
# Author(s) ID                 57201759181;57211516485;16548784600;8922674200;
# Title                      Kinetostatic and dynamic modeling of flexure-b...
# Year                                                                    2020
# Source title                                       Applied Mechanics Reviews
# Volume                                                                    72
# Issue                                                                      3
# Art. No.                                                              030802
# Page start                                                               NaN
# Page end                                                                 NaN
# Page count                                                               NaN
# Cited by                                                                 6.0
# DOI                                                        10.1115/1.4045679
# Link                       https://www.scopus.com/inward/record.uri?eid=2...
# Affiliations               Institute of Systems Engineering, China Academ...
# Authors with affiliations  Ling, M., Institute of Systems Engineering, Ch...
# Abstract                   Flexure-based compliant mechanisms are becomin...
# Author Keywords                                                          NaN
# Index Keywords             Compliant mechanisms; Mechanisms; Precision en...
# Document Type                                                         Review
# Publication Stage                                                      Final
# Access Type                                                      Open Access
# Source                                                                Scopus
# EID                                                       2-s2.0-85083188976
#
#                                                                          182  \
# Authors                                                 Ziaee M., Crane N.B.
# Author(s) ID                                         57191873151;7003772744;
# Title                      Binder jetting: A review of process, materials...
# Year                                                                    2019
# Source title                                          Additive Manufacturing
# Volume                                                                    28
# Issue                                                                    NaN
# Art. No.                                                                 NaN
# Page start                                                               781
# Page end                                                                 801
# Page count                                                               NaN
# Cited by                                                                30.0
# DOI                                              10.1016/j.addma.2019.05.031
# Link                       https://www.scopus.com/inward/record.uri?eid=2...
# Affiliations               Department of Mechanical Engineering, Universi...
# Authors with affiliations  Ziaee, M., Department of Mechanical Engineerin...
# Abstract                   Binder Jet printing is an additive manufacturi...
# Author Keywords            Binder jetting; Materials; Post-processing; Po...
# Index Keywords             Deposition; Electromagnetic wave emission; Mat...
# Document Type                                                         Review
# Publication Stage                                                      Final
# Access Type                                                              NaN
# Source                                                                Scopus
# EID                                                       2-s2.0-85068065294
#
#                                                                          185
# Authors                             Mayoral J.M., Franke K.W., Hutchinson T.
# Author(s) ID                             16481299700;55315026400;7101640734;
# Title                      The September 19, 2017 Mw 7.1 Puebla-Mexico ci...
# Year                                                                    2019
# Source title                        Soil Dynamics and Earthquake Engineering
# Volume                                                                   123
# Issue                                                                    NaN
# Art. No.                                                                 NaN
# Page start                                                               520
# Page end                                                                 524
# Page count                                                               NaN
# Cited by                                                                 1.0
# DOI                                            10.1016/j.soildyn.2019.05.019
# Link                       https://www.scopus.com/inward/record.uri?eid=2...
# Affiliations               National University of Mexico, Mexico City, Me...
# Authors with affiliations  Mayoral, J.M., National University of Mexico, ...
# Abstract                   The September 19th, 2017 Mw 7.1 Puebla-Mexico ...
# Author Keywords            Building damage mapping; Seismic foundation pe...
# Index Keywords             Buildings; Earthquakes; Geotechnical engineeri...
# Document Type                                                         Review
# Publication Stage                                                      Final
# Access Type                                                              NaN
# Source                                                                Scopus
# EID                                                       2-s2.0-85065896666

# %% [markdown]
# ## Loading the CSV into Neo4j
#
# In this step we are going to define the query to load the csv into the graph database. Note that the csv can generate most of the data from the original source. The only relations that have to be faked are "reviewed_by", since we don't have data on who was the reviewer of a paper, and the relation of "cited_by", because in the dataset the cited by column corresponds to the number of citations, not the actual papers who cited the paper per se.

# %%
def load_byu_csv(conn):
    query = """
        LOAD CSV WITH HEADERS FROM 'file:///dataset.csv' AS row
        MERGE (paper: Paper {Title: row.Title})
        SET paper.Content = row.Link,
            paper.Abstract = row.Abstract
        WITH row, paper
        UNWIND row.Authors AS authorstr
        UNWIND apoc.text.split(authorstr, ',') AS authorname
        MERGE (author: Author {AuthorName: authorname})
        MERGE (paper)-[:WRITTEN_BY]->(author)
        WITH paper, row WHERE row.Volume IS NOT NULL
        MERGE (doc: Document {DocumentType: row['Document Type'], Title: row['Source title'], Volume: row['Volume'], Year: row['Year']})
        MERGE (paper)-[:PUBLISHED_AT]->(doc)
        WITH paper, row, row['Document Type'] AS doctype WHERE doctype = 'Conference Paper'
        MERGE (doc: Document {DocumentType: row['Document Type'], Title: row['Source title'], Year: row['Year']})
        MERGE (paper)-[:PUBLISHED_AT]->(doc)
        MERGE (event: Event {EventType: 'Conference', EventName: row['Source title'], ConferenceName: row['General conference name'], Edition: row['Volume'], Year: row['Year']})
        MERGE (doc)-[:PROCEEDING_OF]->(event)
        MERGE (paper)-[:PRESENTED_AT]->(event)
        WITH paper, row['Index Keywords'] as keywordsstr
        UNWIND apoc.text.split(keywordsstr, ';') AS keyword
        MERGE (topic: Topic {Keyword: keyword})
        MERGE (paper)-[:RELATED_TO]->(topic)
    """
    session = conn.driver.session()
    response = list(session.run(query))
    session.close()
    print("Success")

# %%
load_byu_csv(conn)
# Out:
# Success

# %% [markdown]
# This method loads artificially the citations to the graph.

# %%
def create_citations(conn):
    query="""
        MATCH (paps: Paper)
        WITH COLLECT(paps) AS Papers
        MATCH (paper: Paper)
        WITH toInteger(round(rand()*10)) AS citations, paper, Papers
        WITH paper, citations, apoc.coll.randomItems(Papers, citations) AS cited_by_papers
        UNWIND cited_by_papers as cited_by_paper
        WITH paper, cited_by_paper WHERE cited_by_paper.Title <> paper.Title
        MERGE (paper)-[:CITED_BY]->(cited_by_paper)
    """
    session = conn.driver.session()
    response = list(session.run(query))
    session.close()
    print("Success")

# %%
create_citations(conn)
# Out:
# Success

# %% [markdown]
# Similarly, we will create artificially the reviewers in the graph.

# %%
def create_reviews(conn):
    query="""
MATCH (paper: Paper)
WITH paper, apoc.coll.randomItem([0, 1, 2, 3, 4]) AS nreviews
MATCH (a2: Author)
WITH COLLECT(a2) AS reviewerPool, paper, nreviews
WITH paper, apoc.coll.randomItems(reviewerPool, nreviews) AS reviewers
UNWIND reviewers AS reviewer
WITH paper, reviewer
OPTIONAL MATCH (paper)-[w:WRITTEN_BY]->(reviewer)
WITH paper, reviewer WHERE w IS NULL
MERGE (paper)-[:REVIEWED_BY]->(reviewer)
    """
    session = conn.driver.session()
    response = list(session.run(query))
    session.close()
    print("Success")

# %%
create_reviews(conn)
# Out:
# Success
